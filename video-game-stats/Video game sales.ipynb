# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/video-game-sales.csv')
df.dropna()
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
plt.figure(figsize=[18, 12])

for platform in df['Platform'].unique():
    platform_df = df[df['Platform'] == platform].sort_values(by='Year')
    platform_sales = platform_df.groupby('Year')['Global_Sales'].agg(np.sum).values
    platform_years = platform_df['Year'].dropna().unique()
    plt.plot(platform_years, platform_sales, label=platform)

plt.legend()

# n64_df = df[df['Platform'] == 'N64'].sort_values(by='Year')
# n64_sales = n64_df.groupby('Year')['Global_Sales'].agg(np.sum).values
# n64_years = n64_df['Year'].dropna().unique()

# snes_df = df[df['Platform'] == 'SNES'].sort_values(by='Year')
# snes_sales = snes_df.groupby('Year')['Global_Sales'].agg(np.sum).values
# snes_years = snes_df['Year'].dropna().unique()

# %%
# Out:
# Int64Index([15867], dtype='int64')

# %%
df.drop(15867)
# Out:
#         Rank                                 Name Platform    Year   Genre  \
# 15867  15870  Strongest Tokyo University Shogi DS       DS  1985.0  Action
#
#       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 15867     Mycom       0.0       0.0      0.02          0.0          0.02
